# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import json
import random
import pandas as pd
import numpy as np
import requests
import time
import os
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key
#units = "Imperial"
#"&units="+units
#query URL
query_url = url+"&q="

# %%
requests.get(query_url + "Miami")
# Out:
# <Response [200]>

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key
#units = "Imperial"
#"&units="+units
#query URL
query_url = url+"&q="

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# Processing Record 1 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=butaritari
# Processing Record 2 | Atherton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=atherton
# Processing Record 3 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pevek
# Processing Record 4 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fortuna
# City not found. Skipping...
# Processing Record 5 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=punta arenas
# Processing Record 6 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ushuaia
# Processing Record 7 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hobart
# Processing Record 8 | Tigzirt
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tigzirt
# Processing Record 9 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cabo san lucas
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 10 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hermanus
# Processing Record 11 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=avarua
# Processing Record 12 | East London
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=east london
# Processing Record 13 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=beringovskiy
# Processing Record 14 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=half moon bay
# City not found. Skipping...
# Processing Record 15 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rikitea
# Processing Record 16 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=geraldton
# Processing Record 17 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=albany
# Processing Record 18 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=thompson
# City not found. Skipping...
# Processing Record 19 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tasiilaq
# Processing Record 20 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san patricio
# City not found. Skipping...
# Processing Record 21 | Ewa Beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ewa beach
# Processing Record 22 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=atuona
# Processing Record 23 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saskylakh
# Processing Record 24 | Isiolo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=isiolo
# Processing Record 25 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nikolskoye
# Processing Record 26 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tuatapere
# Processing Record 27 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pangnirtung
# Processing Record 28 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=najran
# Processing Record 29 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=antofagasta
# Processing Record 30 | Chapleau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chapleau
# Processing Record 31 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cidreira
# Processing Record 32 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=faya
# Processing Record 33 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sitka
# Processing Record 34 | Kerchevskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kerchevskiy
# Processing Record 35 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=henties bay
# Processing Record 36 | Nicoya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nicoya
# Processing Record 37 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bluff
# Processing Record 38 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bambous virieux
# Processing Record 39 | Skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=skjervoy
# Processing Record 40 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lebu
# Processing Record 41 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mataura
# Processing Record 42 | liliongan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=liliongan
# Processing Record 43 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cayenne
# Processing Record 44 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=klaksvik
# Processing Record 45 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ribeira grande
# City not found. Skipping...
# Processing Record 46 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bilibino
# Processing Record 47 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=te anau
# Processing Record 48 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=upernavik
# Processing Record 49 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vaini
# Processing Record 50 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zyryanka
# Processing Record 51 | Dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dongsheng
# City not found. Skipping...
# Processing Record 52 | Moerai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moerai
# Processing Record 53 | Kendari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kendari
# Processing Record 54 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kodiak
# Processing Record 55 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=flinders
# Processing Record 56 | Bluefields
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bluefields
# Processing Record 57 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sioux lookout
# Processing Record 58 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jalu
# Processing Record 59 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=new norfolk
# Processing Record 60 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vestmannaeyjar
# Processing Record 61 | Murree
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=murree
# Processing Record 62 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ilulissat
# Processing Record 63 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=meulaboh
# Processing Record 64 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hithadhoo
# Processing Record 65 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port alfred
# Processing Record 66 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kapaa
# Processing Record 67 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port elizabeth
# Processing Record 68 | Tezu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tezu
# Processing Record 69 | Ruteng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ruteng
# Processing Record 70 | Rafraf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rafraf
# Processing Record 71 | Pionerskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pionerskiy
# Processing Record 72 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dikson
# Processing Record 73 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cape town
# Processing Record 74 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=puerto ayora
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=khatanga
# Processing Record 76 | Bolobo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bolobo
# Processing Record 77 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yumen
# Processing Record 78 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=clyde river
# Processing Record 79 | High Prairie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=high prairie
# Processing Record 80 | Nata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nata
# Processing Record 81 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=airai
# Processing Record 82 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hilo
# Processing Record 83 | Karpogory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=karpogory
# Processing Record 84 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=grindavik
# Processing Record 85 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ponta do sol
# Processing Record 86 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nishihara
# Processing Record 87 | Rafaela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rafaela
# Processing Record 88 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=talnakh
# Processing Record 89 | Paragominas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=paragominas
# Processing Record 90 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tiksi
# Processing Record 91 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rio grande
# Processing Record 92 | Shemonaikha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shemonaikha
# Processing Record 93 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=busselton
# Processing Record 94 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chuy
# Processing Record 95 | Osorno
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=osorno
# Processing Record 96 | Miyako
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=miyako
# Processing Record 97 | Mococa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mococa
# Processing Record 98 | Starodub
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=starodub
# Processing Record 99 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pisco
# Processing Record 100 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tuktoyaktuk
# Processing Record 101 | Pattani
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pattani
# Processing Record 102 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=leningradskiy
# Processing Record 103 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kavieng
# Processing Record 104 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port lincoln
# Processing Record 105 | Nyurba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nyurba
# City not found. Skipping...
# Processing Record 106 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=itarema
# Processing Record 107 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nome
# Processing Record 108 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=esperance
# City not found. Skipping...
# Processing Record 109 | Mahmudabad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mahmudabad
# Processing Record 110 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ancud
# Processing Record 111 | Verkhnyaya Inta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=verkhnyaya inta
# Processing Record 112 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bethel
# Processing Record 113 | High Level
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=high level
# Processing Record 114 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=comodoro rivadavia
# City not found. Skipping...
# Processing Record 115 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=quelimane
# Processing Record 116 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=arraial do cabo
# Processing Record 117 | Santa Isabel do Rio Negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santa isabel do rio negro
# Processing Record 118 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chokurdakh
# Processing Record 119 | Panjab
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=panjab
# Processing Record 120 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jamestown
# Processing Record 121 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=longyearbyen
# Processing Record 122 | Valjevo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=valjevo
# Processing Record 123 | Dakar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dakar
# City not found. Skipping...
# Processing Record 124 | Santa Barbara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santa barbara
# Processing Record 125 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aklavik
# Processing Record 126 | Zelenogorskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zelenogorskiy
# Processing Record 127 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alofi
# Processing Record 128 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bredasdorp
# City not found. Skipping...
# Processing Record 129 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=provideniya
# Processing Record 130 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=naze
# Processing Record 131 | Tkibuli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tkibuli
# Processing Record 132 | Chantada
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chantada
# Processing Record 133 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rawson
# Processing Record 134 | Almeria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=almeria
# City not found. Skipping...
# Processing Record 135 | Derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=derzhavinsk
# Processing Record 136 | Ystad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ystad
# Processing Record 137 | Coleraine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coleraine
# Processing Record 138 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=namibe
# Processing Record 139 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cockburn town
# Processing Record 140 | Mithi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mithi
# Processing Record 141 | Annau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=annau
# Processing Record 142 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ostrovnoy
# Processing Record 143 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=benguela
# Processing Record 144 | Kumbo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kumbo
# Processing Record 145 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=komsomolskiy
# Processing Record 146 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=praia
# City not found. Skipping...
# Processing Record 147 | Pingyin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pingyin
# Processing Record 148 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lata
# Processing Record 149 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=praia da vitoria
# Processing Record 150 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=georgetown
# Processing Record 151 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=anadyr
# Processing Record 152 | Carbonia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carbonia
# Processing Record 153 | Puerto Carreno
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=puerto carreno
# Processing Record 154 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=qaanaaq
# Processing Record 155 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=havre-saint-pierre
# Processing Record 156 | Iguape
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=iguape
# Processing Record 157 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sao joao da barra
# Processing Record 158 | Calama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=calama
# Processing Record 159 | Cuamba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cuamba
# Processing Record 160 | Deblin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=deblin
# Processing Record 161 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fairbanks
# Processing Record 162 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ketchikan
# Processing Record 163 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rio gallegos
# Processing Record 164 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mayo
# Processing Record 165 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hami
# Processing Record 166 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mao
# Processing Record 167 | Neyshabur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=neyshabur
# City not found. Skipping...
# Processing Record 168 | Dongying
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dongying
# Processing Record 169 | Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aripuana
# Processing Record 170 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port macquarie
# Processing Record 171 | Vitim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vitim
# Processing Record 172 | Villa Carlos Paz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=villa carlos paz
# Processing Record 173 | Zlitan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zlitan
# Processing Record 174 | Saravan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saravan
# Processing Record 175 | Thanh Hoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=thanh hoa
# Processing Record 176 | Pedernales
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pedernales
# Processing Record 177 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=castro
# Processing Record 178 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yar-sale
# Processing Record 179 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ahipara
# City not found. Skipping...
# Processing Record 180 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shingu
# Processing Record 181 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santa fe
# Processing Record 182 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=oussouye
# City not found. Skipping...
# Processing Record 183 | Chingola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chingola
# Processing Record 184 | Buraydah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=buraydah
# City not found. Skipping...
# Processing Record 185 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cherskiy
# Processing Record 186 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=severo-kurilsk
# Processing Record 187 | Pangai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pangai
# Processing Record 188 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carnarvon
# Processing Record 189 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=touros
# Processing Record 190 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vila velha
# Processing Record 191 | Itacare
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=itacare
# Processing Record 192 | Ramnagar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ramnagar
# Processing Record 193 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=labuhan
# Processing Record 194 | Monte Alegre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=monte alegre
# Processing Record 195 | Piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=piacabucu
# Processing Record 196 | Fort Nelson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fort nelson
# Processing Record 197 | Tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tocopilla
# Processing Record 198 | Usinsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=usinsk
# Processing Record 199 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carutapera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 200 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sao filipe
# Processing Record 201 | Miranda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=miranda
# City not found. Skipping...
# Processing Record 202 | Venezuela
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=venezuela
# Processing Record 203 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alice springs
# Processing Record 204 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yerbogachen
# Processing Record 205 | Catalao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=catalao
# City not found. Skipping...
# Processing Record 206 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kavaratti
# Processing Record 207 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sur
# Processing Record 208 | San Juan de la Maguana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san juan de la maguana
# Processing Record 209 | Kamskiye Polyany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kamskiye polyany
# Processing Record 210 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bathsheba
# Processing Record 211 | Nelson Bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nelson bay
# Processing Record 212 | Kwakoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kwakoa
# Processing Record 213 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=necochea
# Processing Record 214 | Alamogordo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alamogordo
# Processing Record 215 | Rajanpur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rajanpur
# City not found. Skipping...
# Processing Record 216 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port hardy
# Processing Record 217 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yellowknife
# Processing Record 218 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=caravelas
# Processing Record 219 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint-philippe
# Processing Record 220 | Chupaca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chupaca
# Processing Record 221 | Punta Cardon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=punta cardon
# Processing Record 222 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=haines junction
# City not found. Skipping...
# Processing Record 223 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saldanha
# Processing Record 224 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zhigansk
# Processing Record 225 | Chaihe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chaihe
# Processing Record 226 | Amapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=amapa
# Processing Record 227 | Providencia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=providencia
# City not found. Skipping...
# Processing Record 228 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gizo
# Processing Record 229 | Galle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=galle
# Processing Record 230 | Kirovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kirovskiy
# Processing Record 231 | Kisarazu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kisarazu
# Processing Record 232 | La Sarre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=la sarre
# Processing Record 233 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=victoria
# Processing Record 234 | Morro Bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=morro bay
# Processing Record 235 | Abalak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=abalak
# Processing Record 236 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kaitangata
# Processing Record 237 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=broken hill
# Processing Record 238 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=koumac
# Processing Record 239 | Kemise
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kemise
# Processing Record 240 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=okhotsk
# Processing Record 241 | Limon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=limon
# Processing Record 242 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dingle
# Processing Record 243 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sisimiut
# Processing Record 244 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=flin flon
# Processing Record 245 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=poum
# Processing Record 246 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=barrow
# Processing Record 247 | Darab
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=darab
# Processing Record 248 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guerrero negro
# Processing Record 249 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=narsaq
# City not found. Skipping...
# Processing Record 250 | Oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=oksfjord
# Processing Record 251 | Uusikaupunki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=uusikaupunki
# Processing Record 252 | Keningau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=keningau
# City not found. Skipping...
# Processing Record 253 | Zharkovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zharkovskiy
# Processing Record 254 | Mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mwinilunga
# Processing Record 255 | Sri Aman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sri aman
# Processing Record 256 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mar del plata
# Processing Record 257 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=faanui
# Processing Record 258 | Alyth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alyth
# City not found. Skipping...
# Processing Record 259 | Guanica
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guanica
# Processing Record 260 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kahului
# Processing Record 261 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vardo
# Processing Record 262 | Doctor Juan Leon Mallorquin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=doctor juan leon mallorquin
# Processing Record 263 | Tete
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tete
# Processing Record 264 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vao
# Processing Record 265 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tautira
# Processing Record 266 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san andres
# Processing Record 267 | Pahrump
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pahrump
# Processing Record 268 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=egvekinot
# Processing Record 269 | Novo Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=novo aripuana
# Processing Record 270 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hambantota
# Processing Record 271 | Megion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=megion
# Processing Record 272 | Jacareacanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jacareacanga
# Processing Record 273 | Montemorelos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=montemorelos
# Processing Record 274 | Saint Stephen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint stephen
# Processing Record 275 | Guerrero
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guerrero
# Processing Record 276 | Nerchinskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nerchinskiy zavod
# Processing Record 277 | Dublin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dublin
# Processing Record 278 | Hamina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hamina
# Processing Record 279 | Maningrida
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=maningrida
# Processing Record 280 | Mount Isa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mount isa
# Processing Record 281 | Abha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=abha
# City not found. Skipping...
# Processing Record 282 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mount gambier
# Processing Record 283 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tura
# Processing Record 284 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint anthony
# Processing Record 285 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coquimbo
# City not found. Skipping...
# Processing Record 286 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coihaique
# Processing Record 287 | Buta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=buta
# Processing Record 288 | Aleksandrovskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aleksandrovskiy zavod
# Processing Record 289 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=westport
# City not found. Skipping...
# Processing Record 290 | Mezen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mezen
# Processing Record 291 | Whitecourt
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=whitecourt
# Processing Record 292 | Esso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=esso
# Processing Record 293 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=general roca
# City not found. Skipping...
# Processing Record 294 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dunedin
# Processing Record 295 | Ossora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ossora
# Processing Record 296 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=luderitz
# Processing Record 297 | Nabire
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nabire
# Processing Record 298 | Parrita
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=parrita
# Processing Record 299 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pangody
# City not found. Skipping...
# Processing Record 300 | Mbalmayo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mbalmayo
# Processing Record 301 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=maceio
# Processing Record 302 | Puerto Ayacucho
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=puerto ayacucho
# Processing Record 303 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=beyneu
# Processing Record 304 | Bogorodskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bogorodskoye
# Processing Record 305 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=erenhot
# Processing Record 306 | Aygedzor
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aygedzor
# Processing Record 307 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=adrar
# City not found. Skipping...
# Processing Record 308 | Bereda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bereda
# Processing Record 309 | Svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=svetlogorsk
# Processing Record 310 | Portsmouth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=portsmouth
# Processing Record 311 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=banda aceh
# Processing Record 312 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=waingapu
# Processing Record 313 | Denpasar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=denpasar
# Processing Record 314 | Rancho Palos Verdes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rancho palos verdes
# Processing Record 315 | Goderich
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=goderich
# Processing Record 316 | Coolum Beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coolum beach
# Processing Record 317 | Doka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=doka
# Processing Record 318 | Galeana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=galeana
# Processing Record 319 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mahebourg
# Processing Record 320 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=omsukchan
# Processing Record 321 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=norman wells
# ...
# Processing Record 455 | Manicore
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=manicore
# Processing Record 456 | Mae Hong Son
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mae hong son
# Processing Record 457 | Arona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=arona
# City not found. Skipping...
# Processing Record 458 | Yaan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yaan
# Processing Record 459 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lompoc
# Processing Record 460 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=paita
# Processing Record 461 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=brae
# Processing Record 462 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=avera
# Processing Record 463 | New Lenox
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=new lenox
# Processing Record 464 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sistranda
# Processing Record 465 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jining
# Processing Record 466 | Trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=trincomalee
# Processing Record 467 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hualmay
# Processing Record 468 | Gashua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gashua
# Processing Record 469 | Yarada
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yarada
# Processing Record 470 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alyangula
# Processing Record 471 | Padang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=padang
# Processing Record 472 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=eyl
# Processing Record 473 | Huarmey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=huarmey
# Processing Record 474 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san quintin
# Processing Record 475 | Aller
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aller
# Processing Record 476 | Cocal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cocal
# Processing Record 477 | Warmbad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=warmbad
# Processing Record 478 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=torbay
# Processing Record 479 | Lagoa da Prata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lagoa da prata
# Processing Record 480 | Hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hukuntsi
# Processing Record 481 | Kokopo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kokopo
# Processing Record 482 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint george
# Processing Record 483 | Pudozh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pudozh
# Processing Record 484 | Vallenar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vallenar
# Processing Record 485 | Priargunsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=priargunsk
# Processing Record 486 | Kidal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kidal
# Processing Record 487 | Teya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=teya
# Processing Record 488 | Bria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bria
# Processing Record 489 | Sarankhola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sarankhola
# Processing Record 490 | Rio Tercero
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rio tercero
# City not found. Skipping...
# Processing Record 491 | Dhule
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dhule
# Processing Record 492 | Madimba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=madimba
# Processing Record 493 | Moree
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moree
# Processing Record 494 | Huittinen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=huittinen
# Processing Record 495 | Sao Jose da Coroa Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sao jose da coroa grande
# Processing Record 496 | Nara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nara
# Processing Record 497 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bay roberts
# Processing Record 498 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kindu
# Processing Record 499 | Cuauhtemoc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cuauhtemoc
# Processing Record 500 | Astorga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=astorga
# Processing Record 501 | Panzhihua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=panzhihua
# Processing Record 502 | Tagusao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tagusao
# Processing Record 503 | Bekhteyevka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bekhteyevka
# Processing Record 504 | Guayaramerin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guayaramerin
# Processing Record 505 | Iquique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=iquique
# Processing Record 506 | Teknaf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=teknaf
# Processing Record 507 | Esperanza
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=esperanza
# Processing Record 508 | Kafanchan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kafanchan
# City not found. Skipping...
# Processing Record 509 | Olga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=olga
# Processing Record 510 | Aksay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aksay
# Processing Record 511 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lavrentiya
# Processing Record 512 | Sahuaripa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sahuaripa
# Processing Record 513 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=conde
# Processing Record 514 | Gull Lake
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gull lake
# Processing Record 515 | Kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kudahuvadhoo
# Processing Record 516 | Jiayuguan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jiayuguan
# Processing Record 517 | Verkhnyaya Toyma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=verkhnyaya toyma
# Processing Record 518 | Cilegon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cilegon
# Processing Record 519 | Boffa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=boffa
# Processing Record 520 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yatou
# Processing Record 521 | Bontang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bontang
# Processing Record 522 | Virginia Beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=virginia beach
# Processing Record 523 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=constitucion
# Processing Record 524 | Moura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moura
# Processing Record 525 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ambilobe
# Processing Record 526 | Tanah Merah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tanah merah
# Processing Record 527 | Huntsville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=huntsville
# Processing Record 528 | Naryan-Mar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=naryan-mar
# Processing Record 529 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aykhal
# Processing Record 530 | Sainte-Marie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sainte-marie
# Processing Record 531 | Sambava
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sambava
# Processing Record 532 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mahibadhoo
# Processing Record 533 | Ramona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ramona
# Processing Record 534 | Uddevalla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=uddevalla
# Processing Record 535 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bilma
# Processing Record 536 | Hinton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hinton
# Processing Record 537 | Aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aginskoye
# Processing Record 538 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sorland
# Processing Record 539 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=muros
# Processing Record 540 | Voi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=voi
# Processing Record 541 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=salinopolis
# Processing Record 542 | Porirua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=porirua
# Processing Record 543 | Yangambi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yangambi
# Processing Record 544 | Shambu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shambu
# Processing Record 545 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=marsh harbour
# Processing Record 546 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mehamn
# Processing Record 547 | Guozhen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guozhen
# Processing Record 548 | Montlucon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=montlucon
# Processing Record 549 | Poronaysk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=poronaysk
# Processing Record 550 | Agirish
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=agirish
# Processing Record 551 | el Prat de Llobregat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=el prat de llobregat
# Processing Record 552 | Arroio Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=arroio grande
# Processing Record 553 | Lucea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lucea
# Processing Record 554 | Bafoulabe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bafoulabe
# Processing Record 555 | Kayankulam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kayankulam
# City not found. Skipping...
# Processing Record 556 | Gladstone
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gladstone
# City not found. Skipping...
# Processing Record 557 | Quballat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=quballat
# Processing Record 558 | Zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zhezkazgan
# Processing Record 559 | Vincennes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vincennes
# Processing Record 560 | Gangoh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gangoh
# Processing Record 561 | Lagos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lagos
# Processing Record 562 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=takoradi
# Processing Record 563 | Brazzaville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=brazzaville

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness": cloudiness, 
    "Country": country,
    "Date": date, 
    "Humidity": humidity,
    "Lat": lat, 
    "Lng": lng, 
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

#to csv
weather_data.to_csv(r"weather_data.csv",index=False)

# Display count of weather data values 
weather_data.count()
# Out:
# City          563
# Cloudiness    563
# Country       563
# Date          563
# Humidity      563
# Lat           563
# Lng           563
# Max Temp      563
# Wind Speed    563
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display data frame head 
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Butaritari          49      KI  1573343187        65   3.07  172.79
# 1      Atherton          28      AU  1573343187        33 -17.27  145.48
# 2         Pevek           0      RU  1573343188        75  69.70  170.27
# 3       Fortuna           1      US  1573343188        87  40.60 -124.16
# 4  Punta Arenas           0      CL  1573343188        52 -53.16  -70.91
#
#    Max Temp  Wind Speed
# 0     83.82        1.30
# 1     90.00        4.70
# 2      5.81        3.65
# 3     60.01        9.17
# 4     46.40        8.05

# %%
time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].min()))
# Out:
# '11/09/19'

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 9 columns):
# City          563 non-null object
# Cloudiness    563 non-null int64
# Country       563 non-null object
# Date          563 non-null int64
# Humidity      563 non-null int64
# Lat           563 non-null float64
# Lng           563 non-null float64
# Max Temp      563 non-null float64
# Wind Speed    563 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.7+ KB

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y",time.localtime(weather_data["Date"].max()))
# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature ($^o$F)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({day})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({day})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
