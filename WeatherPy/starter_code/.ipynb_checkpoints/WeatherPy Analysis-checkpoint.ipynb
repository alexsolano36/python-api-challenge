# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import json
import random
import pandas as pd
import numpy as np
import requests
import time
import os
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key
#units = "Imperial"
#"&units="+units
#query URL
query_url = url+"&q="

# %%
requests.get(query_url + "Miami")
# Out:
# <Response [200]>

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + api_key
#units = "Imperial"
#"&units="+units
#query URL
query_url = url+"&q="

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=thompson
# Processing Record 2 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=khatanga
# Processing Record 3 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mataura
# Processing Record 4 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jamestown
# Processing Record 5 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=codrington
# Processing Record 6 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=naze
# Processing Record 7 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=alofi
# Processing Record 8 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=punta arenas
# Processing Record 9 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carnarvon
# Processing Record 10 | Shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shaunavon
# Processing Record 11 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=souillac
# Processing Record 12 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tiksi
# Processing Record 13 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint-philippe
# Processing Record 14 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vao
# Processing Record 15 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rikitea
# Processing Record 16 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bambous virieux
# Processing Record 17 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=salinas
# Processing Record 18 | Pontes e Lacerda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pontes e lacerda
# Processing Record 19 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=salalah
# Processing Record 20 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pevek
# Processing Record 21 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hobart
# Processing Record 22 | Teknaf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=teknaf
# Processing Record 23 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=castro
# Processing Record 24 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=new norfolk
# Processing Record 25 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mar del plata
# Processing Record 26 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ushuaia
# City not found. Skipping...
# Processing Record 27 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hilo
# Processing Record 28 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kapaa
# Processing Record 29 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=georgetown
# Processing Record 30 | Sahuaripa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sahuaripa
# Processing Record 31 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=havre-saint-pierre
# Processing Record 32 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rawson
# Processing Record 33 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fairbanks
# Processing Record 34 | Ureki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ureki
# Processing Record 35 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=albany
# Processing Record 36 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=buala
# City not found. Skipping...
# Processing Record 37 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tautira
# Processing Record 38 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kavieng
# Processing Record 39 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=victoria
# Processing Record 40 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=busselton
# Processing Record 41 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kodinsk
# Processing Record 42 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cape town
# Processing Record 43 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mahebourg
# Processing Record 44 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=butaritari
# Processing Record 45 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=puerto ayora
# Processing Record 46 | Gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gushikawa
# Processing Record 47 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=airai
# Processing Record 48 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=labuhan
# Processing Record 49 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yellowknife
# Processing Record 50 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port-gentil
# City not found. Skipping...
# Processing Record 51 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yerbogachen
# Processing Record 52 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hambantota
# Processing Record 53 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port hardy
# Processing Record 54 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hay river
# City not found. Skipping...
# Processing Record 55 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bluff
# Processing Record 56 | Kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kropotkin
# Processing Record 57 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bredasdorp
# Processing Record 58 | Umm Lajj
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=umm lajj
# Processing Record 59 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port lincoln
# Processing Record 60 | Novaya Igirma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=novaya igirma
# Processing Record 61 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cherskiy
# Processing Record 62 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=erenhot
# Processing Record 63 | Guadalajara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guadalajara
# Processing Record 64 | Naraina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=naraina
# City not found. Skipping...
# Processing Record 65 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kruisfontein
# Processing Record 66 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=palmer
# Processing Record 67 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=xining
# Processing Record 68 | Yemelyanovo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yemelyanovo
# Processing Record 69 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=faanui
# Processing Record 70 | Obregon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=obregon
# Processing Record 71 | Ratnagiri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ratnagiri
# Processing Record 72 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vaini
# Processing Record 73 | Hirara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hirara
# Processing Record 74 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kavaratti
# Processing Record 75 | Guider
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guider
# Processing Record 76 | Rio Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rio grande
# Processing Record 77 | Unity
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=unity
# Processing Record 78 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tuktoyaktuk
# Processing Record 79 | North Battleford
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=north battleford
# Processing Record 80 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saskylakh
# Processing Record 81 | Wajir
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=wajir
# Processing Record 82 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tilichiki
# Processing Record 83 | Vredendal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vredendal
# Processing Record 84 | Dabat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dabat
# Processing Record 85 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=olinda
# Processing Record 86 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lata
# Processing Record 87 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=barrow
# Processing Record 88 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hithadhoo
# City not found. Skipping...
# Processing Record 89 | Simmerath
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=simmerath
# City not found. Skipping...
# Processing Record 90 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chokurdakh
# Processing Record 91 | Carpinteria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carpinteria
# Processing Record 92 | Mingshui
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mingshui
# Processing Record 93 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=avarua
# City not found. Skipping...
# Processing Record 94 | Praia da Vitoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=praia da vitoria
# Processing Record 95 | Muros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=muros
# Processing Record 96 | Altus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=altus
# Processing Record 97 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=atuona
# Processing Record 98 | Taurage
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=taurage
# Processing Record 99 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lebu
# Processing Record 100 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moron
# Processing Record 101 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fortuna
# Processing Record 102 | Acajutla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=acajutla
# Processing Record 103 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san quintin
# Processing Record 104 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port alfred
# Processing Record 105 | North Bend
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=north bend
# Processing Record 106 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port blair
# Processing Record 107 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pitimbu
# Processing Record 108 | Koumac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=koumac
# Processing Record 109 | Dabhol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dabhol
# City not found. Skipping...
# Processing Record 110 | Port Macquarie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port macquarie
# Processing Record 111 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ribeira grande
# Processing Record 112 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=quelimane
# City not found. Skipping...
# Processing Record 113 | Williamsport
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=williamsport
# Processing Record 114 | Betsiamites
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=betsiamites
# Processing Record 115 | Grafton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=grafton
# Processing Record 116 | Sihora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sihora
# Processing Record 117 | Pontianak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pontianak
# Processing Record 118 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=longyearbyen
# Processing Record 119 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kiama
# Processing Record 120 | Oschatz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=oschatz
# Processing Record 121 | Onokhoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=onokhoy
# Processing Record 122 | Berezna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=berezna
# Processing Record 123 | Tshikapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tshikapa
# Processing Record 124 | Abu Samrah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=abu samrah
# Processing Record 125 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saldanha
# Processing Record 126 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=geraldton
# Processing Record 127 | Amberieu-en-Bugey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=amberieu-en-bugey
# City not found. Skipping...
# Processing Record 128 | Sompeta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sompeta
# Processing Record 129 | Camacha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=camacha
# Processing Record 130 | Tobane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tobane
# Processing Record 131 | Pemba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pemba
# Processing Record 132 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tual
# Processing Record 133 | La Orilla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=la orilla
# Processing Record 134 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=komsomolskiy
# Processing Record 135 | Manicore
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=manicore
# Processing Record 136 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=necochea
# Processing Record 137 | Jeremie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jeremie
# Processing Record 138 | Great Falls
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=great falls
# Processing Record 139 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=okhotsk
# Processing Record 140 | Baza
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=baza
# Processing Record 141 | Kontagora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kontagora
# Processing Record 142 | Ewa Beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ewa beach
# Processing Record 143 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=thinadhoo
# City not found. Skipping...
# Processing Record 144 | Umm Kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=umm kaddadah
# Processing Record 145 | Verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=verkhoyansk
# Processing Record 146 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hermanus
# Processing Record 147 | College
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=college
# Processing Record 148 | Dawei
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dawei
# Processing Record 149 | Camalu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=camalu
# Processing Record 150 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=paita
# Processing Record 151 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sao joao da barra
# City not found. Skipping...
# Processing Record 152 | Zambezi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zambezi
# Processing Record 153 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ilulissat
# Processing Record 154 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=avera
# Processing Record 155 | Mandan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mandan
# Processing Record 156 | Yuzhou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yuzhou
# Processing Record 157 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint george
# Processing Record 158 | Sabzevar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sabzevar
# Processing Record 159 | Peleduy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=peleduy
# Processing Record 160 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kodiak
# Processing Record 161 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ponta do sol
# Processing Record 162 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cabo san lucas
# Processing Record 163 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=provideniya
# Processing Record 164 | Asopos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=asopos
# Processing Record 165 | Rauma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rauma
# Processing Record 166 | Zistersdorf
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zistersdorf
# Processing Record 167 | Taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=taoudenni
# Processing Record 168 | Gold Coast
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gold coast
# Processing Record 169 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mao
# Processing Record 170 | Ouricuri
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ouricuri
# Processing Record 171 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cidreira
# Processing Record 172 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=severo-kurilsk
# Processing Record 173 | Sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sinnamary
# Processing Record 174 | Porto Walter
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=porto walter
# Processing Record 175 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=upernavik
# Processing Record 176 | East London
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=east london
# Processing Record 177 | Westport
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=westport
# Processing Record 178 | Houston
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=houston
# Processing Record 179 | Rexburg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rexburg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 180 | Srivardhan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=srivardhan
# Processing Record 181 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=arraial do cabo
# Processing Record 182 | Augustow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=augustow
# Processing Record 183 | Gawler
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gawler
# Processing Record 184 | Ongandjera
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ongandjera
# Processing Record 185 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shingu
# Processing Record 186 | Tangjiazhuang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tangjiazhuang
# Processing Record 187 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rocha
# Processing Record 188 | Tongren
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tongren
# Processing Record 189 | Kungurtug
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kungurtug
# Processing Record 190 | Tateyama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tateyama
# Processing Record 191 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=klaksvik
# Processing Record 192 | Filingue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=filingue
# Processing Record 193 | Fez
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fez
# Processing Record 194 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kamenka
# Processing Record 195 | Redwater
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=redwater
# Processing Record 196 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=port elizabeth
# City not found. Skipping...
# Processing Record 197 | Karlstad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=karlstad
# Processing Record 198 | Kununurra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kununurra
# Processing Record 199 | Adrar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=adrar
# Processing Record 200 | Manoharpur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=manoharpur
# Processing Record 201 | Camacari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=camacari
# Processing Record 202 | Nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nouadhibou
# Processing Record 203 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dingle
# Processing Record 204 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=clyde river
# Processing Record 205 | Trairi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=trairi
# Processing Record 206 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bubaque
# Processing Record 207 | Bakaly
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bakaly
# Processing Record 208 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aklavik
# Processing Record 209 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=burnie
# Processing Record 210 | Lumut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lumut
# Processing Record 211 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=leningradskiy
# Processing Record 212 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=te anau
# Processing Record 213 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=beringovskiy
# Processing Record 214 | Marsabit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=marsabit
# Processing Record 215 | Kyzyl-Suu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kyzyl-suu
# Processing Record 216 | Novyy Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=novyy urengoy
# Processing Record 217 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kahului
# Processing Record 218 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ostrovnoy
# Processing Record 219 | Lianzhou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lianzhou
# Processing Record 220 | Nago
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nago
# Processing Record 221 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=narsaq
# Processing Record 222 | Santa Ines
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santa ines
# City not found. Skipping...
# Processing Record 223 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=torbay
# Processing Record 224 | Waddan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=waddan
# Processing Record 225 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kalmunai
# City not found. Skipping...
# Processing Record 226 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bonavista
# Processing Record 227 | Tupi Paulista
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tupi paulista
# City not found. Skipping...
# Processing Record 228 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yulara
# Processing Record 229 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mehamn
# Processing Record 230 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sibolga
# Processing Record 231 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=katsuura
# Processing Record 232 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nanortalik
# Processing Record 233 | Suihua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=suihua
# Processing Record 234 | Hit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hit
# Processing Record 235 | Tandil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tandil
# Processing Record 236 | Dole
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dole
# Processing Record 237 | Cabo Rojo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cabo rojo
# Processing Record 238 | Barcelos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=barcelos
# City not found. Skipping...
# Processing Record 239 | Bosaso
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bosaso
# Processing Record 240 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kirakira
# Processing Record 241 | Pareora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pareora
# Processing Record 242 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=laguna
# Processing Record 243 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chuy
# Processing Record 244 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pacific grove
# Processing Record 245 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ahipara
# Processing Record 246 | Santa Fe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santa fe
# Processing Record 247 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=maceio
# Processing Record 248 | Lysyye Gory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lysyye gory
# Processing Record 249 | Berea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=berea
# City not found. Skipping...
# Processing Record 250 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=norman wells
# Processing Record 251 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coahuayana
# Processing Record 252 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=broome
# Processing Record 253 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=waingapu
# Processing Record 254 | Soligalich
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=soligalich
# Processing Record 255 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sitka
# Processing Record 256 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tasiilaq
# Processing Record 257 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gorontalo
# Processing Record 258 | Salina Cruz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=salina cruz
# Processing Record 259 | Abnub
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=abnub
# Processing Record 260 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bathsheba
# Processing Record 261 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=baruun-urt
# Processing Record 262 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nikolskoye
# Processing Record 263 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vila franca do campo
# Processing Record 264 | Kostino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kostino
# Processing Record 265 | Fare
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=fare
# Processing Record 266 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cayenne
# Processing Record 267 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pisco
# Processing Record 268 | Eagle Pass
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=eagle pass
# Processing Record 269 | Kahramanmaras
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kahramanmaras
# Processing Record 270 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=belaya gora
# Processing Record 271 | Sorata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sorata
# City not found. Skipping...
# Processing Record 272 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=solnechnyy
# Processing Record 273 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mogadishu
# City not found. Skipping...
# Processing Record 274 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=guerrero negro
# Processing Record 275 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kaitangata
# Processing Record 276 | Talnakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=talnakh
# Processing Record 277 | Koulikoro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=koulikoro
# Processing Record 278 | Beloha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=beloha
# Processing Record 279 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=oistins
# Processing Record 280 | Flin Flon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=flin flon
# Processing Record 281 | Atar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=atar
# Processing Record 282 | Algete
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=algete
# Processing Record 283 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint-augustin
# Processing Record 284 | Shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shenjiamen
# Processing Record 285 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=henties bay
# Processing Record 286 | Solikamsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=solikamsk
# Processing Record 287 | Pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pangkalanbuun
# Processing Record 288 | Honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=honningsvag
# City not found. Skipping...
# Processing Record 289 | Kuchinarai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kuchinarai
# Processing Record 290 | Ternate
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ternate
# Processing Record 291 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=esperance
# Processing Record 292 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hofn
# Processing Record 293 | Boende
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=boende
# Processing Record 294 | Abeche
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=abeche
# Processing Record 295 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint-francois
# City not found. Skipping...
# Processing Record 296 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=luderitz
# Processing Record 297 | Seydi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=seydi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 298 | Sarakhs
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sarakhs
# Processing Record 299 | Berezovyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=berezovyy
# Processing Record 300 | Baker City
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=baker city
# Processing Record 301 | Kedrovyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kedrovyy
# Processing Record 302 | Ludza
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ludza
# Processing Record 303 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=iqaluit
# Processing Record 304 | Uvira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=uvira
# City not found. Skipping...
# Processing Record 305 | Kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kloulklubed
# Processing Record 306 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=udachnyy
# Processing Record 307 | Kollegal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kollegal
# Processing Record 308 | Severo-Yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=severo-yeniseyskiy
# Processing Record 309 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=namibe
# Processing Record 310 | Jiaocheng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jiaocheng
# Processing Record 311 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=dikson
# Processing Record 312 | Xixiang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=xixiang
# Processing Record 313 | Santiago del Estero
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=santiago del estero
# Processing Record 314 | Udine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=udine
# Processing Record 315 | Lebyazhye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lebyazhye
# Processing Record 316 | Novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=novobirilyussy
# Processing Record 317 | Mildura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mildura
# Processing Record 318 | Cedar Falls
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cedar falls
# Processing Record 319 | Kericho
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kericho
# Processing Record 320 | Stromness
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=stromness
# Processing Record 321 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=coihaique
# Processing Record 322 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lagoa
# Processing Record 323 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ancud
# Processing Record 324 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=qaanaaq
# Processing Record 325 | Malanville
# ...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=canton
# Processing Record 448 | Brokopondo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=brokopondo
# Processing Record 449 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=lorengau
# City not found. Skipping...
# Processing Record 450 | Moree
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moree
# City not found. Skipping...
# Processing Record 451 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=constitucion
# Processing Record 452 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=saint anthony
# Processing Record 453 | Ban Nahin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ban nahin
# Processing Record 454 | Bijar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bijar
# City not found. Skipping...
# Processing Record 455 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=luanda
# Processing Record 456 | Shangzhi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=shangzhi
# Processing Record 457 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cap malheureux
# City not found. Skipping...
# Processing Record 458 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=samarai
# Processing Record 459 | Burns Lake
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=burns lake
# Processing Record 460 | Kerema
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kerema
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 461 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=inhambane
# Processing Record 462 | Longyan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=longyan
# Processing Record 463 | Yugorsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yugorsk
# Processing Record 464 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=puerto colombia
# Processing Record 465 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=vila velha
# City not found. Skipping...
# Processing Record 466 | Grand Gaube
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=grand gaube
# Processing Record 467 | Qeshm
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=qeshm
# Processing Record 468 | Boueni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=boueni
# City not found. Skipping...
# Processing Record 469 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=maragogi
# City not found. Skipping...
# Processing Record 470 | Severobaykalsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=severobaykalsk
# Processing Record 471 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=wanning
# Processing Record 472 | Katete
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=katete
# Processing Record 473 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ketchikan
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 474 | Palm Beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=palm beach
# Processing Record 475 | Marsh Harbour
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=marsh harbour
# Processing Record 476 | Goundam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=goundam
# Processing Record 477 | Siderno
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=siderno
# Processing Record 478 | Kuryk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kuryk
# Processing Record 479 | Twin Falls
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=twin falls
# Processing Record 480 | Okha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=okha
# Processing Record 481 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san patricio
# Processing Record 482 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nemuro
# Processing Record 483 | Kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kulhudhuffushi
# Processing Record 484 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=gizo
# Processing Record 485 | Yuzha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yuzha
# City not found. Skipping...
# Processing Record 486 | Carballo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=carballo
# Processing Record 487 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=qaqortoq
# Processing Record 488 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=juneau
# Processing Record 489 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=daru
# Processing Record 490 | Ust-Kuyga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ust-kuyga
# Processing Record 491 | Grand-Santi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=grand-santi
# Processing Record 492 | Kuito
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=kuito
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 493 | Jerome
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jerome
# Processing Record 494 | Watrous
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=watrous
# Processing Record 495 | Pachino
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pachino
# Processing Record 496 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hami
# Processing Record 497 | Nikita
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nikita
# Processing Record 498 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=flinders
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 499 | Weligama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=weligama
# Processing Record 500 | Moussoro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=moussoro
# Processing Record 501 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=haines junction
# Processing Record 502 | Giaveno
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=giaveno
# Processing Record 503 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=chapais
# Processing Record 504 | Pastos Bons
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pastos bons
# Processing Record 505 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=san vicente
# City not found. Skipping...
# Processing Record 506 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=christchurch
# Processing Record 507 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hobyo
# Processing Record 508 | Morgan City
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=morgan city
# City not found. Skipping...
# Processing Record 509 | Aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aripuana
# Processing Record 510 | Borgarnes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=borgarnes
# Processing Record 511 | Mayor Pablo Lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mayor pablo lagerenza
# City not found. Skipping...
# Processing Record 512 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jining
# Processing Record 513 | Russell
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=russell
# Processing Record 514 | Ostrogozhsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ostrogozhsk
# Processing Record 515 | Mananum
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mananum
# Processing Record 516 | Itaituba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=itaituba
# Processing Record 517 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tura
# Processing Record 518 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=manta
# City not found. Skipping...
# Processing Record 519 | Batagay-Alyta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=batagay-alyta
# Processing Record 520 | Rochegda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=rochegda
# Processing Record 521 | Ouidah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ouidah
# Processing Record 522 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sisimiut
# Processing Record 523 | Nichinan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=nichinan
# Processing Record 524 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=takoradi
# Processing Record 525 | Pumiao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=pumiao
# Processing Record 526 | Iztapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=iztapa
# Processing Record 527 | Jumla
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=jumla
# Processing Record 528 | Cortes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cortes
# Processing Record 529 | Marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=marsaxlokk
# Processing Record 530 | Mana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mana
# Processing Record 531 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=hovd
# Processing Record 532 | Igrim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=igrim
# Processing Record 533 | Talas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=talas
# Processing Record 534 | Sola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sola
# Processing Record 535 | Zanjan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=zanjan
# Processing Record 536 | Erzin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=erzin
# Processing Record 537 | Acari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=acari
# Processing Record 538 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aksarka
# Processing Record 539 | Yendi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=yendi
# Processing Record 540 | Bilma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=bilma
# Processing Record 541 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tessalit
# Processing Record 542 | Sumenep
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sumenep
# Processing Record 543 | Mitchell
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mitchell
# Processing Record 544 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=ciudad bolivar
# Processing Record 545 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=biak
# Processing Record 546 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=sept-iles
# City not found. Skipping...
# Processing Record 547 | Houma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=houma
# City not found. Skipping...
# Processing Record 548 | Mecca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=mecca
# Processing Record 549 | Penzance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=penzance
# Processing Record 550 | Tottori
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=tottori
# Processing Record 551 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=aasiaat
# Processing Record 552 | Cocorit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=9180b27af3acb3bc0ec802e5c3b2b8c6&q=cocorit

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness": cloudiness, 
    "Country": country,
    "Date": date, 
    "Humidity": humidity,
    "Lat": lat, 
    "Lng": lng, 
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

#to csv
weather_data.to_csv(r"weather_data.csv",index=False)

# Display count of weather data values 
weather_data.count()
# Out:
# City          552
# Cloudiness    552
# Country       552
# Date          552
# Humidity      552
# Lat           552
# Lng           552
# Max Temp      552
# Wind Speed    552
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display data frame head 
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Thompson          20      CA  1573340870        71  55.74  -97.86
# 1    Khatanga         100      RU  1573341025        96  71.98  102.47
# 2     Mataura         100      NZ  1573341026        89 -46.19  168.86
# 3   Jamestown           0      AU  1573340912        30 -33.21  138.60
# 4  Codrington          90      AU  1573341028        55 -28.95  153.24
#
#    Max Temp  Wind Speed
# 0      5.00        8.05
# 1     -1.72       15.90
# 2     50.00        4.00
# 3     65.61        4.09
# 4     69.01        6.93

# %%
time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].min()))
# Out:
# '11/09/19'

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552 entries, 0 to 551
# Data columns (total 9 columns):
# City          552 non-null object
# Cloudiness    552 non-null int64
# Country       552 non-null object
# Date          552 non-null int64
# Humidity      552 non-null int64
# Lat           552 non-null float64
# Lng           552 non-null float64
# Max Temp      552 non-null float64
# Wind Speed    552 non-null float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 38.9+ KB

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y",time.localtime(weather_data["Date"].max()))
# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature ($^o$F)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({day})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness ({day})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], edgecolors="black")
plt.grid()
day = time.strftime("%m/%d/%y", time.localtime(weather_data["Date"].max()))

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.jpg")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
